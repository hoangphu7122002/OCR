# %%
import requests
url = "https://viettelai.vn/ocr/id_card"
payload={}
files=[
    ('image_front',('file',open('/raid/phundh/vai_ocr_api/image/87190492_175440417089548_7539014665137815552_n.jpg','rb'),'image/jpeg')),
    ('image_back',('file',open('/raid/phundh/vai_ocr_api/image/87177558_896723910781958_3771419415501864960_n.jpg','rb'),'image/jpeg'))
]
headers = {}
response = requests.request("POST", url, headers=headers, data=payload, files=files)
print(response.text)
# Out:
# {"code":1,"message":"Success.","request_id":"9e4c4f61-44b1-40c2-8b36-32664c315ba9","information":{"id":"191973998","name":"NGUYỄN ĐẮC HOÀNG PHÚ","birthday":"07/12/2002","birthplace":"Phong An, Phong Điền, Thừa Thiên Huế","sex":"","address":"Phong An, Phong Điền, Thừa Thiên Huế","province":"Thừa Thiên Huế","district":"Phong Điền","ward":"Phong An","province_code":"46","district_code":"476","ward_code":"19858","street":"","nationality":"","religion":"Không","ethnicity":"Kinh","expiry":"","feature":"Nốt ruồi c1,5cm dưới trước mép trái","issue_date":"04/06/2018","issue_by":"TỈNH T.T.HUẾ","licence_class":null,"passport_id":null,"cmnd_id":"","passport_type":null,"military_title":null,"type_blood":null,"type":"CMND","type_list":"back, front","document":"CMND_back,CMND_front","mrz1":"","mrz2":"","mrz3":"","hometown":"","marital_status":"","father_name":"","father_nationality":"","mother_name":"","mother_nationality":"","spouse_name":"","spouse_nationality":"","representative_name":"","repres
# ...

# %%
import requests
url = "https://viettelai.vn/ocr/car_testing"
payload={'token': '35d212f9d54a5ca483b622571ffc3950'}
files=[
('file',('file',open('/raid/phundh/vai_ocr_api/image/dangkiem.jpeg','rb'),'image/jpeg'))
]
headers = {
'accept': '*/*'
}
response = requests.request("POST", url, headers=headers, data=payload, files=files)
# response = requests.request("POST", url, headers=headers, files=files)
print(response.text)
# Out:
# {"code":415,"en_message":"Bad data","vi_message":"File ảnh gửi lên bị hỏng hoặc định dạng file không được hỗ trợ"}

# %%
import requests
url = "https://viettelai.vn/ocr/business_register"
payload={'token': '35d212f9d54a5ca483b622571ffc3950'}
files=[
('file',('file',open('/raid/phundh/vai_ocr_api/image/giay-chung-nhan-dang-ky-ho-kinh-doanh-ca-the.jpeg','rb'),'image/jpeg'))
]
headers = {
'accept': '*/*'
}
response = requests.request("POST", url, headers=headers, data=payload, files=files)
print(response.text)
# Out:
# {"code":415,"en_message":"Bad data","vi_message":"File ảnh gửi lên bị hỏng hoặc định dạng file không được hỗ trợ"}

# %%
import requests
url = "https://viettelai.vn/ocr/scan_to_docx"
payload = {'token': '35d212f9d54a5ca483b622571ffc3950'}
files=[
('file',('file',open('/raid/phundh/vai_ocr_api/image/20160917_123454.jpg','rb'),'image/jpeg'))
]
headers = {
'accept': '*/*',
'Content-Type': 'multipart/form-data; boundary=----WebKitFormBoundary12345'
}
response = requests.request("POST", url, headers=headers, data=payload, files=files)
print(response.text)
# Out:
# <html><body><script>document.cookie="D1N=e813289349bb26991f4774acd3424898"+"; expires=Fri, 31 Dec 2099 23:59:59 GMT; path=/";window.location.reload(true);</script></body></html>

# %%
import requests
url = "https://viettelai.vn/plate/detect_plate"
payload = {"token":"35d212f9d54a5ca483b622571ffc3950"}
payload = {}
files=[
('file',('file',open('/raid/phundh/vai_ocr_api/image/y-nghia-bien-so-xe-theo-phong-thuy.jpg','rb'),'image/jpeg'))
]

response = requests.request("POST", url, data=payload, files=files)
print(response.text)
# Out:
# {
#   "confident": 1.0,
#   "description": "",
#   "elapsed_time": 2400,
#   "end_time": 1734402056227,
#   "model": "model",
#   "number": "",
#   "response_code": 200,
#   "start_time": 1734402053827
# }
